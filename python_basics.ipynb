# %% [markdown]
# # Python Basics in Jupyter Notebook
#
# This notebook demonstrates basic Python functionality in VS Code's Jupyter integration.

# %%
# Basic print statement
print("Hello from Jupyter in VS Code!")

# %% [markdown]
# ## Variables and Basic Operations

# %%
# Variables
x = 10
y = 5

# Basic operations
print(f"Addition: {x} + {y} = {x + y}")
print(f"Subtraction: {x} - {y} = {x - y}")
print(f"Multiplication: {x} * {y} = {x * y}")
print(f"Division: {x} / {y} = {x / y}")
print(f"Integer Division: {x} // {y} = {x // y}")
print(f"Modulus: {x} % {y} = {x % y}")
print(f"Exponentiation: {x} ** {y} = {x ** y}")

# %% [markdown]
# ## Lists and Loops

# %%
# Creating a list
fruits = ["apple", "banana", "cherry", "orange", "kiwi"]
print(f"Fruits list: {fruits}")

# Accessing elements
print(f"First fruit: {fruits[0]}")
print(f"Last fruit: {fruits[-1]}")

# Looping through a list
print("\nAll fruits:")
for fruit in fruits:
    print(f"- {fruit}")

# %% [markdown]
# ## Data Visualization with Matplotlib
#
# This section demonstrates how to create a simple plot using matplotlib.

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt

# Generate data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a plot
plt.figure(figsize=(10, 6))
plt.plot(x, y, 'b-', label='sin(x)')
plt.title('Sine Wave')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Working with NumPy Arrays

# %%
# Create arrays
arr1 = np.array([1, 2, 3, 4, 5])
arr2 = np.array([6, 7, 8, 9, 10])

print(f"Array 1: {arr1}")
print(f"Array 2: {arr2}")

# Array operations
print(f"\nSum: {arr1 + arr2}")
print(f"Product: {arr1 * arr2}")
print(f"Square root of arr1: {np.sqrt(arr1)}")
print(f"Mean of arr2: {np.mean(arr2)}")

# %% [markdown]
# ## Interactive Input
#
# You can also get user input in Jupyter notebooks.

# %%
name = input("Enter your name: ")
print(f"Hello, {name}! Welcome to Jupyter notebooks in VS Code.")
